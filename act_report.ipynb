# %% [markdown]
# <a href="https://colab.research.google.com/github/EricOdhiambo/wrangling-and-Analyzing-data/blob/main/act_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Report: act_report

# %% [markdown]
# The twitter_archive_master.csv that was created from assessing, cleaning and joining the data frames was further programmatically assessed and meaningful insights could be drawn from it. The file was first read from being a csv file into a data frame called wrangled_data. Using the *describe()* function on the data frame, a a table of useful statistic of of the different columns in the data frame was availled. These stats included count, mean, standard deviation denoted as std, min to describe minimum value, 25% for 25th percentile, 50% for 50 percentile, 75% pfor 75th percentile and maax to display the maximum value.

# %% [markdown]
# ![Useful Statistics.png](data:image/png;base64,...)

# %% [markdown]
# *image 1 - A table of statistics for the twitter_archive_master.csv*

# %% [markdown]
# Some of the insights which were able to be drawn from the statistical table included:
#
#
#  * The average for retweet_count was 2821.756944
#
#  * The highest value in the favorite_count column is 107956
#
#  * The minimum value in the retweet_count column is 23

# %% [markdown]
# I further created a simple data frame called name_and_rating from the master data frame columns 'name' and 'rating_numerator'. This was done to try and check the distribution of different dogs according to their ratings. This would even give more insight on the master data. The disrtibution that was plotted was for the first 20 entries as shown. It was discovered that most of the first 20 dogs' ratings are between 12/10 and 13/10.

# %% [markdown]
# ![Screenshot (74).png](data:image/png;base64,...)

# %% [markdown]
# *image of a section showing creation of a new data frame called name_and_rating that would only have two columns i.e 'name' and 'rating_numerator'.*
# *The first 20 elements of the name_and_rating rating would be printed. Note-The image displays a section of the data frame*

# %% [markdown]
# ![first 20 dogs by names and rating_numarator distribution.png](data:image/png;base64,...)

# %% [markdown]
# *image of distribution of the first 20 dogs in the twitter_archive_master.csv by rating numerator against dog name*
